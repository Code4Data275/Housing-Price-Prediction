# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict,GridSearchCV
from sklearn.metrics import r2_score,mean_squared_error
# %matplotlib inline

# %% [markdown]
# ### Load the Dataset

# %%
filepath='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'

# %%
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# #### Datatypes of the attributes

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# #### Statistical Summary of Data

# %%
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# #### Dropping irrelevant columns

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### Statistical Summary

# %%
df.describe(include='all')
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21600.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.372870
# std     2.876566e+09              NaN  3.671272e+05      0.926657
# min     1.000102e+06              NaN  7.500000e+04      1.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21603.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %% [markdown]
# #### Checking null values

# %%
df.isnull().sum()
# Out:
# id                0
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %%
df['bedrooms'].isnull().sum()
# Out:
# 13

# %%
df['bathrooms'].isnull().sum()
# Out:
# 10

# %% [markdown]
# #### Removing Null Values

# %%
#Replacing Missing Values in 'bedrooms' column with its mean
avg_bedrooms = df['bedrooms'].astype('float').mean()
df.replace(np.NaN,avg_bedrooms,inplace=True)

# %%
#Replacing Missing Values in 'bathrooms' column with its mean
avg_bathrooms = df['bathrooms'].astype('float').mean()
df.replace(np.NaN,avg_bathrooms,inplace=True)

# %%
df['bedrooms'].isnull().sum()
# Out:
# 0

# %%
df['bathrooms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Number of Houses with unique floor values

# %%
floor_counts = df['floors'].value_counts().to_frame()
floor_counts.reset_index(inplace=True)
floor_counts
# Out:
#    floors  count
# 0     1.0  10680
# 1     2.0   8241
# 2     1.5   1910
# 3     3.0    613
# 4     2.5    161
# 5     3.5      8

# %%
df['waterfront'].value_counts().to_frame()
# Out:
#             count
# waterfront
# 0           21450
# 1             163

# %% [markdown]
# #### Box Plot for determing outliers in waterfront data

# %%
sns.boxplot(x='waterfront',y='price',data=df)
plt.ylim(0,)
plt.show()

# %% [markdown]
# #### Regression plot to check the correlation for sqt_above data

# %%
sns.regplot(x='sqft_above',y='price',data=df)
plt.ylim(0,)
plt.show()

# %%
df[['sqft_above','price']].corr()
# Out:
#             sqft_above     price
# sqft_above    1.000000  0.605567
# price         0.605567  1.000000

# %%
df_numeric = df.select_dtypes(include=[np.number])
df_numeric.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525223
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# #### Build a Simple LR model for 'sqft_living' and check its R^2 score

# %%
X = df[['sqft_living']]
Y = df['price']

# %%
lr = LinearRegression()

# %%
lr.fit(X,Y)
# Out:
# LinearRegression()

# %%
lr.score(X,Y)
# Out:
# 0.4928532179037931

# %% [markdown]
# #### Build a Multiple LR Model and check its R^2 score

# %%
Z = df[["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]]

# %%
lr.fit(Z,Y)
# Out:
# LinearRegression()

# %%
lr.score(Z,Y)
# Out:
# 0.657692084618949

# %% [markdown]
# #### Build a pipeline for multiple features in the dataset, fit the model and check its score

# %%
Input = [('scale',StandardScaler()),('polynomial',PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
pipe = Pipeline(Input)

# %%
pipe.fit(Z,Y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
pipe.score(Z,Y)
# Out:
# 0.7512941411995129

# %% [markdown]
# #### Split the Training Data and Testing Data

# %%
x_train,x_test,y_train,y_test = train_test_split(Z,Y,test_size=0.15,random_state=1)

# %%
x_train.shape[0]
# Out:
# 18371

# %%
x_test.shape[0]
# Out:
# 3242

# %% [markdown]
# #### Build a Ridge Regression Model and fit the training data and check the score of tested data

# %%
RidgeModel = Ridge(alpha=0.1)

# %%
RidgeModel.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
RidgeModel.score(x_test,y_test)
# Out:
# 0.647865900687053

# %% [markdown]
# #### Perform second order Polynomial Transformation and build a regression model

# %%
pr = PolynomialFeatures(degree=2)

# %%
x_train_pr = pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)

# %%
RidgeModel = Ridge(alpha=0.1)

# %%
RidgeModel.fit(x_train_pr,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
yhat = RidgeModel.predict(x_test_pr)

# %%
r2_score(y_test,yhat)
# Out:
# 0.7001498461737303
